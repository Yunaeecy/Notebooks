# %% [markdown]
# # Introduction to the Example Dataset

# %%
import pandas as pd

# Creating a basic example dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emily'],
    'Age': [25, 30, 22, 35, 28],
    'Salary': [50000, 60000, 45000, 70000, 55000],
    'Department': ['HR', 'Finance', 'IT', 'Marketing', 'HR']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary Department
# 0    Alice   25   50000         HR
# 1      Bob   30   60000    Finance
# 2  Charlie   22   45000         IT
# 3    David   35   70000  Marketing
# 4    Emily   28   55000         HR

# %% [markdown]
# # Bin data into internals

# %%
# Binning data into internal
bins = [0,30,40,50,float('inf')]
labels = ['<30','30-40','40-50','50+']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)
df
# Out:
#       Name  Age  Salary Department AgeGroup
# 0    Alice   25   50000         HR      <30
# 1      Bob   30   60000    Finance      <30
# 2  Charlie   22   45000         IT      <30
# 3    David   35   70000  Marketing    30-40
# 4    Emily   28   55000         HR      <30

# %% [markdown]
# # String operations

# %%
# String operaions on a column
df['NameLength']=df['Name'].apply(len)

# %% [markdown]
# # Rename columns

# %%
df.rename(columns={'Salary':'MonthlySalary'}, inplace=True)
df
# Out:
#       Name  Age  MonthlySalary Department AgeGroup  NameLength
# 0    Alice   25          50000         HR      <30           5
# 1      Bob   30          60000    Finance      <30           3
# 2  Charlie   22          45000         IT      <30           7
# 3    David   35          70000  Marketing    30-40           5
# 4    Emily   28          55000         HR      <30           5

# %% [markdown]
# # Credit
#
# https://python.plainenglish.io/essential-python-pandas-codes-to-elevate-your-data-analysis-skills-4fa986357986
