# %% [markdown]
# <a href="https://www.kaggle.com/code/yunasheng/array-datastructure?scriptVersionId=165850338" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# array
class PartyArray:
    def __init__(self):
        self.data = []
    def __len__(self):
        return len(self.data)
    def remove(self,value):
        self.data.remove(value)
    def append(self, value):
        """
        add new value to the end
        """
        self.data.append(value)

p=PartyArray()
print(type(p))
# Out:
# <class '__main__.PartyArray'>

# %%
p.append(1)
print(p)

# %%
print(len(p))
# Out:
# 1

# %%
p.append(2)

# %%
print(len(p))
# Out:
# 2

# %%
p.remove(2)
print(len(p))
# Out:
# 1
