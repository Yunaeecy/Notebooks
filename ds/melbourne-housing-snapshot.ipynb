# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/melbourne-housing-snapshot/melb_data.csv')

# %%
df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df.shape
# Out:
# (13580, 21)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.nunique()
# Out:
# Suburb             314
# Address          13378
# Rooms                9
# Type                 3
# Price             2204
# Method               5
# SellerG            268
# Date                58
# Distance           202
# Postcode           198
# Bedroom2            12
# Bathroom             9
# Car                 11
# Landsize          1448
# BuildingArea       602
# YearBuilt          144
# CouncilArea         33
# Lattitude         6503
# Longtitude        7063
# Regionname           8
# Propertycount      311
# dtype: int64

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
df['Suburb'].value_counts()
# Out:
# Suburb
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: count, Length: 314, dtype: int64

# %%
df['Address'].value_counts()
# Out:
# Address
# 36 Aberfeldie St    3
# 2 Bruce St          3
# 5 Charles St        3
# 53 William St       3
# 14 Arthur St        3
#                    ..
# 16 Alleford St      1
# 2/1073 Centre Rd    1
# 14 Columbia St      1
# 21 Hardy Ct         1
# 6 Agnes St          1
# Name: count, Length: 13378, dtype: int64

# %%
df['Rooms'].value_counts()
# Out:
# Rooms
# 3     5881
# 2     3648
# 4     2688
# 1      681
# 5      596
# 6       67
# 7       10
# 8        8
# 10       1
# Name: count, dtype: int64

# %%
df['Type'].value_counts()
# Out:
# Type
# h    9449
# u    3017
# t    1114
# Name: count, dtype: int64

# %%
df['Price'].value_counts()
# Out:
# Price
# 1100000.0    113
# 1300000.0    109
# 650000.0     109
# 800000.0     109
# 600000.0     104
#             ...
# 1928000.0      1
# 2236000.0      1
# 601500.0       1
# 550500.0       1
# 1323000.0      1
# Name: count, Length: 2204, dtype: int64

# %%
df['Method'].value_counts()
# Out:
# Method
# S     9022
# SP    1703
# PI    1564
# VB    1199
# SA      92
# Name: count, dtype: int64

# %%
df['Bedroom2'].value_counts()
# Out:
# Bedroom2
# 3.0     5896
# 2.0     3737
# 4.0     2601
# 1.0      691
# 5.0      556
# 6.0       63
# 0.0       16
# 7.0       10
# 8.0        5
# 9.0        3
# 20.0       1
# 10.0       1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data= df.groupby('Type')['Price'].mean().reset_index(), x='Type', y='Price', palette='coolwarm')
plt.title('Average Price by Type')
plt.xlabel('Type')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %%
sns.pairplot(df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
plt.scatter(df['Price'],df['Rooms'])

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data= df.groupby('Rooms')['Price'].mean().reset_index(), x='Rooms', y='Price', palette='coolwarm')
plt.title('Average Price by Rooms')
plt.xlabel('Rooms')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(df['Price'],df['Type'])

# %%
plt.scatter(df['Price'],df['Bathroom'])

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data= df.groupby('Bathroom')['Price'].mean().reset_index(), x='Bathroom', y='Price', palette='coolwarm')
plt.title('Average Price by Bathroom')
plt.xlabel('Bathroom')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(df['Price'],df['Car'])

# %%
plt.figure(figsize=(10, 8))
sns.barplot(data= df.groupby('Car')['Price'].mean().reset_index(), x='Car', y='Price', palette='coolwarm')
plt.title('Average Price by Car')
plt.xlabel('Car')
plt.ylabel('Average Price')
plt.xticks(rotation=0)
plt.show()

# %%
plt.scatter(df['Price'],df['YearBuilt'])

# %%
plt.figure(figsize=(30,12))
sns.barplot(data= df.groupby('YearBuilt')['Price'].mean().reset_index(), x='YearBuilt', y='Price', palette='coolwarm')
plt.title('Average Price by YearBuilt')
plt.xlabel('YearBuilt')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.barplot(data= df.groupby('CouncilArea')['Price'].mean().reset_index(), x='CouncilArea', y='Price', palette='coolwarm')
plt.title('Average Price by CouncilArea')
plt.xlabel('CouncilAreat')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df['Price'],df['Regionname'])

# %%
plt.figure(figsize=(12,8))
sns.barplot(data= df.groupby('Regionname')['Price'].mean().reset_index(), x='Regionname', y='Price', palette='coolwarm')
plt.title('Average Price by Regionname')
plt.xlabel('Regionname')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df['Price'],df['Propertycount'])

# %%
plt.figure(figsize=(35,12))
sns.barplot(data= df.groupby('Propertycount')['Price'].mean().reset_index(), x='Propertycount', y='Price', palette='coolwarm')
plt.title('Average Price by Propertycount')
plt.xlabel('Propertycount')
plt.ylabel('Average Price')
plt.xticks(rotation=85)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                   Rooms     Price  Distance  Postcode  Bedroom2  Bathroom  \
# Rooms          1.000000  0.496634  0.294203  0.055303  0.944190  0.592934
# Price          0.496634  1.000000 -0.162522  0.107867  0.475951  0.467038
# Distance       0.294203 -0.162522  1.000000  0.431514  0.295927  0.127155
# Postcode       0.055303  0.107867  0.431514  1.000000  0.060584  0.113664
# Bedroom2       0.944190  0.475951  0.295927  0.060584  1.000000  0.584685
# Bathroom       0.592934  0.467038  0.127155  0.113664  0.584685  1.000000
# Car            0.408483  0.238979  0.262994  0.050289  0.405325  0.322246
# Landsize       0.025678  0.037507  0.025004  0.024558  0.025646  0.037130
# BuildingArea   0.124127  0.090981  0.099481  0.055475  0.122319  0.111933
# YearBuilt     -0.065413 -0.323617  0.246379  0.032863 -0.053319  0.152702
# Lattitude      0.015948 -0.212934 -0.130723 -0.406104  0.015925 -0.070594
# Longtitude     0.100771  0.203656  0.239425  0.445357  0.102238  0.118971
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
pd.crosstab(df['Type'], df['Rooms'])
# Out:
# Rooms   1     2     3     4    5   6   7   8   10
# Type
# h       58  1398  4801  2517  591  66  10   7   1
# t       11   319   629   150    5   0   0   0   0
# u      612  1931   451    21    0   1   0   1   0

# %%
pd.crosstab(df['Type'], df['Method'])
# Out:
# Method    PI     S  SA    SP   VB
# Type
# h       1069  6507  66  1079  728
# t        134   723   7   143  107
# u        361  1792  19   481  364

# %%
pd.crosstab(df['Type'], df['SellerG'])
# Out:
# SellerG  @Realty  ASL  Abercromby's  Ace  Alexkarbon  Allens  Anderson  \
# Type
# h              2    4            13    2          18       1         0
# t              0    0             4    0           7       1         0
# u              0    0             4    0          15       0         5
#
# SellerG  Appleby  Aquire  Area  ...  Zahn  buyMyplace  hockingstuart  \
# Type                            ...
# h              2       1     1  ...     1           2            673
# t              0       0     0  ...     0           1             97
# u              0       0     0  ...     0           0            397
#
# SellerG  hockingstuart/Advantage  hockingstuart/Barry  hockingstuart/Village  \
# Type
# h                              0                    1                      0
# t                              0                    0                      0
# u                              1                    0                      1
#
# SellerG  iOne  iProperty  iSell  iTRAK
# ...

# %%
pd.crosstab(df['Type'], df['Postcode'])
# Out:
# Postcode  3000.0  3002.0  3003.0  3006.0  3008.0  3011.0  3012.0  3013.0  \
# Type
# h              1       5       8       3       0     125     173     141
# t              0       1       8       0       1      18      32       7
# u             45      16      15      38       2      51      37      16
#
# Postcode  3015.0  3016.0  ...  3803.0  3805.0  3806.0  3807.0  3808.0  3809.0  \
# Type                      ...
# h            157      94  ...       5       7      13       1       1       1
# t             18       9  ...       0       0       0       0       0       0
# u             13      23  ...       0       0       0       1       0       0
#
# Postcode  3810.0  3910.0  3976.0  3977.0
# Type
# h              3       4       4       8
# t              0       0       0       0
# u              0       2       0       0
#
# [3 rows x 198 columns]

# %%
pd.crosstab(df['Type'], df['Landsize'])
# Out:
# Landsize  0.0       1.0       2.0       3.0       5.0       10.0      \
# Type
# h              171         1         0         0         1         0
# t              139         0         0         1         0         0
# u             1629         1         1         0         0         1
#
# Landsize  14.0      15.0      17.0      18.0      ...  21700.0   21715.0   \
# Type                                              ...
# h                0         0         0         0  ...         0         0
# t                0         1         0         0  ...         0         0
# u                1         1         1         1  ...         1         1
#
# Landsize  37000.0   38490.0   40468.0   41400.0   44500.0   75100.0   \
# Type
# h                0         1         1         1         1         1
# t                0         0         0         0         0         0
# u                2         0         0         0         0         0
#
# Landsize  76000.0   433014.0
# Type
# ...

# %%
pd.crosstab(df['Type'], df['Propertycount'])
# Out:
# Propertycount  249.0    389.0    394.0    438.0    457.0    534.0    538.0    \
# Type
# h                    1        6        2        7        2        3        1
# t                    0        0        0        0        0        0        0
# u                    0        0        0        0        0        3        0
#
# Propertycount  570.0    588.0    608.0    ...  14949.0  15321.0  15510.0  \
# Type                                      ...
# h                    2       21        7  ...      152       35       44
# t                    0        4        0  ...       18        2        3
# u                    0        1        2  ...       90        8        0
#
# Propertycount  15542.0  16166.0  17055.0  17093.0  17384.0  17496.0  21650.0
# Type
# h                   13       48       23       13        3        1      253
# t                    0        0        0        0        0        0       27
# ...

# %%
pd.crosstab(df['Type'], df['Regionname'])
# Out:
# Regionname  Eastern Metropolitan  Eastern Victoria  Northern Metropolitan  \
# Type
# h                           1173                50                   2754
# t                            118                 0                    307
# u                            180                 3                    829
#
# Regionname  Northern Victoria  South-Eastern Metropolitan  \
# Type
# h                          41                         388
# t                           0                          25
# u                           0                          37
#
# Regionname  Southern Metropolitan  Western Metropolitan  Western Victoria
# Type
# h                            2721                  2290                32
# t                             425                   239                 0
# u                            1549                   419                 0

# %%
pd.crosstab(df['Type'], df['Longtitude'])
# Out:
# Longtitude  144.43181  144.48571  144.54237  144.54532  144.55106  144.55666  \
# Type
# h                   1          1          1          1          1          1
# t                   0          0          0          0          0          0
# u                   0          0          0          0          0          0
#
# Longtitude  144.55784  144.55833  144.55857  144.55888  ...  145.41081  \
# Type                                                    ...
# h                   1          1          1          1  ...          1
# t                   0          0          0          0  ...          0
# u                   0          0          0          0  ...          0
#
# Longtitude  145.41288  145.42554  145.43003  145.43698  145.44530  145.45376  \
# Type
# h                   1          1          1          1          1          1
# t                   0          0          0          0          0          0
# ...

# %%
pd.crosstab(df['Type'], df['Rooms'], values= df['Price'], aggfunc= "sum")
# Out:
# Rooms           1             2             3             4             5   \
# Type
# h       50278200.0  1.422098e+09  5.325429e+09  3.680567e+09  1.109500e+09
# t        6519750.0  2.265406e+08  6.193818e+08  1.825638e+08  5.175000e+06
# u      238636501.0  1.178857e+09  3.836190e+08  2.178700e+07           NaN
#
# Rooms           6           7           8         10
# Type
# h      123387500.0  19207000.0  10572000.0  900000.0
# t              NaN         NaN         NaN       NaN
# u         520000.0         NaN   2250000.0       NaN

# %% [markdown]
# # Credit:
#
#
#
# https://www.kaggle.com/code/shroukelnagdy/melbourne-housing-snapshot
