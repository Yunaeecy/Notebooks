# %% [markdown]
# <a href="https://www.kaggle.com/code/yunasheng/youtube-comments-dataset?scriptVersionId=220248472" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Step 1: Load the Dataset and Explore

# %%
import pandas as pd
import re

# %%
# Load the dataset
df = pd.read_csv('/kaggle/input/youtube-comments-dataset/YoutubeCommentsDataSet.csv')

# Check the first few rows
df.head()
# Out:
#                                              Comment Sentiment
# 0  lets not forget that apple pay in 2014 require...   neutral
# 1  here in nz 50 of retailers don’t even have con...  negative
# 2  i will forever acknowledge this channel with t...  positive
# 3  whenever i go to a place that doesn’t take app...  negative
# 4  apple pay is so convenient secure and easy to ...  positive

# %%
# Check for Missing Values
df.isnull().sum()
# Out:
# Comment      44
# Sentiment     0
# dtype: int64

# %% [markdown]
# # Credit:
#
# https://www.kaggle.com/code/bhavyam24/youtube-comments-dataset/notebook
