# %% [markdown]
# <div style="text-align: center"><img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/0*VT2hHvhHJpuJxSrD.jpeg" width="100%" heigh="100%" alt="Retrieve&Re-Rank pipeline"></div>

# %% [markdown]
# Whether you are a seasoned pro or just dipping your toes into the world of data using Python as a data analyst, data scientist, or going by any other title, these libraries are an absolute must-know. We all know that manual exploratory data analysis(EDA) can be time-consuming. especially when we are diving into new data. It eats up hours of our days to analyze and understand the data.
#
# In this article, I will share `five` different `Python-supported packages` that will transform the way you analyze data. These packages automate your data-analyzing tasks and perform EDA with ease and speed. It also gives an overview of the data and delivers a thorough and comprehensive analysis that allows you to visualize the data easily and gain valuable insights.

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

# read the data 
data = pd.read_csv('/kaggle/input/housing-prices-dataset/Housing.csv')
data.columns = data.columns.str.upper()   #convert the columns to uppercase 
data
# Out:
# /tmp/ipykernel_18/1578331084.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:90% !important; }</style>
#         PRICE  AREA  BEDROOMS  BATHROOMS  STORIES MAINROAD GUESTROOM BASEMENT  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     HOTWATERHEATING AIRCONDITIONING  PARKING PREFAREA FURNISHINGSTATUS
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %% [markdown]
# The dataset consists of 545 rows of data; there are 12 independent variables (bedrooms, bathrooms, parking, etc.) that provide various attributes related to house price and one target dependent variable (PIRCE).

# %% [markdown]
# # 1.Dtale
# Dtale is an open-souce library that offers comprehensive insights into your data through a user-friendly interface for exploration and visualization. It accomplishes almost every aspect of EDA that we require, and the great thing about these packages is that we can also export the code for each visualization we create. To get started, install the packages using pip install and run the provided code as shown below.

# %%
#install the dtale package
# !pip install dtale  # from inside jupyter notebook or
# !pip install dtale # from terminal
# !pip install ipython
# Out:
# Collecting dtale
#   Downloading dtale-3.10.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting dash-colorscales (from dtale)
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.4 MB/s eta 0:00:00
# done
# Collecting dash-daq (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 16.5 MB/s eta 0:00:00
# done
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.14-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: future>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from dtale) (0.18.3)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: missingno in /opt/conda/lib/python3.10/site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from dtale) (2.2.0)
# Requirement already satisfied: squarify in /opt/conda/lib/python3.10/site-packages (from dtale) (0.4.3)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from dtale) (4.12.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from dtale) (2023.11.17)
# Collecting flask-ngrok (from dtale)
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: lz4 in /opt/conda/lib/python3.10/site-packages (from dtale) (4.3.3)
# Requirement already satisfied: cycler in /opt/conda/lib/python3.10/site-packages (from dtale) (0.12.1)
# Collecting dash-bootstrap-components<=1.3.1 (from dtale)
#   Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting dash (from dtale)
#   Downloading dash-2.15.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from dtale) (0.12.2)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from dtale) (0.14.1)
# Requirement already satisfied: werkzeug in /opt/conda/lib/python3.10/site-packages (from dtale) (3.0.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from dtale) (3.2.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from dtale) (1.2.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from dtale) (1.24.4)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /opt/conda/lib/python3.10/site-packages (from dtale) (3.1.2)
# Requirement already satisfied: xarray in /opt/conda/lib/python3.10/site-packages (from dtale) (2024.1.0)
# Requirement already satisfied: et-xmlfile in /opt/conda/lib/python3.10/site-packages (from dtale) (1.1.0)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.10/site-packages (from dtale) (5.18.0)
# Collecting Flask<2.3 (from dtale)
#   Downloading Flask-2.2.5-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: itsdangerous in /opt/conda/lib/python3.10/site-packages (from dtale) (2.1.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from dtale) (2.31.0)
# Requirement already satisfied: contourpy in /opt/conda/lib/python3.10/site-packages (from dtale) (1.2.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from dtale) (3.7.4)
# Requirement already satisfied: scipy!=1.12.0rc1 in /opt/conda/lib/python3.10/site-packages (from dtale) (1.11.4)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/conda/lib/python3.10/site-packages (from dash->dtale) (4.9.0)
# Requirement already satisfied: retrying in /opt/conda/lib/python3.10/site-packages (from dash->dtale) (1.3.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from dash->dtale) (1.5.8)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from dash->dtale) (69.0.3)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.10/site-packages (from dash->dtale) (6.11.0)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.10/site-packages (from Flask<2.3->dtale) (3.1.2)
# Requirement already satisfied: click>=8.0 in /opt/conda/lib/python3.10/site-packages (from Flask<2.3->dtale) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly->dtale) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly->dtale) (21.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug->dtale) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->dtale) (2.5)
# Requirement already satisfied: brotli in /opt/conda/lib/python3.10/site-packages (from Flask-Compress->dtale) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtale) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtale) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtale) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtale) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->dtale) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->dtale) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->dtale) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->dtale) (1.26.18)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->dtale) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->dtale) (3.2.0)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->dtale) (0.5.6)
# Collecting packaging (from plotly->dtale)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata->dash->dtale) (3.17.0)
# Downloading dtale-3.10.0-py2.py3-none-any.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 5.6 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-1.3.1-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 10.5 MB/s eta 0:00:00
# Downloading dash-2.15.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 60.9 MB/s eta 0:00:00
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading Flask-2.2.5-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.8/101.8 kB 4.4 MB/s eta 0:00:00
# Downloading Flask_Compress-1.14-py3-none-any.whl (8.4 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.9 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.5 MB/s eta 0:00:00
# Building wheels for collected packages: dash-colorscales, dash-daq
# done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62567 sha256=522cfe93cc52fe3de1fab453323b81e8ebb558fb18eb0b29dd5dc872a2eac80a
#   Stored in directory: /root/.cache/pip/wheels/70/6a/1f/95b2135cd2c895f0cd8b5d6d6ae7d5ed0a883580b34a31a14d
# done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669692 sha256=2b990e67e6cfadea9d677ddb3536a4b46e21a1f8f880d5a699152f0177597d67
#   Stored in directory: /root/.cache/pip/wheels/75/14/1b/208d09d5e239391048bdc167759977b41ba65a3d4063aebf6b
# Successfully built dash-colorscales dash-daq
# Installing collected packages: strsimpy, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, xlrd, packaging, Flask, flask-ngrok, Flask-Compress, dash, dash-daq, dash-bootstrap-components, dtale
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.0.1
#     Uninstalling Flask-3.0.1:
#       Successfully uninstalled Flask-3.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# jupyterlab 4.0.11 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.2 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.8.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed Flask-2.2.5 Flask-Compress-1.14 dash-2.15.0 dash-bootstrap-components-1.3.1 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.10.0 flask-ngrok-0.0.25 kaleido-0.2.1 packaging-23.2 strsimpy-0.2.1 xlrd-2.0.1
# Requirement already satisfied: ipython in /opt/conda/lib/python3.10/site-packages (8.20.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.10/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.10/site-packages (from ipython) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)

# %%
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.1.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: PyYAML>=5.1 in /opt/conda/lib/python3.10/site-packages (from pyngrok) (6.0.1)
# Downloading pyngrok-7.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.1.2

# %%
# import the library
import dtale
import dtale.app as dtale_app

# dataa = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv')
d = dtale.show(data)
d
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://f3888f64a5e0:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# After executing the code above, the results will be displayed in your editor or browser. It offers a comprehensive analysis, allowing us to check for missing values, duplicates, min/max/mean values, perform correlation analysis, plot various graphs, and much more.

# %% [markdown]
# # 2. Sweetviz
# If you’re looking to save and document your data analysis findings in HTML format, then Sweetviz is the ideal choice. It offers interactive analytical results, allowing you to dive deeper into your data and discover valuable insights. Simply install the packages and run the code below.

# %%
#installing the package
# !pip install sweetviz # from inside jupyter notebook
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (2.2.0)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (1.24.4)
# Requirement already satisfied: matplotlib>=3.1.3 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (3.7.4)
# Requirement already satisfied: tqdm>=4.43.0 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (4.66.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (1.11.4)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (3.1.2)
# Requirement already satisfied: importlib-resources>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from sweetviz) (6.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.4)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 46.5 MB/s eta 0:00:00
# Installing collected packages: sweetviz
# Successfully installed sweetviz-2.3.1

# %%
# analysis report with sweetviz
import sweetviz as sv

# make analysis and assign the target feature
sweet_report = sv.analyze(data , target_feat='PRICE') 

# view the analysis result in browser 
sweet_report.show_html()

# save the analysis result into html
sweet_report.show_html('analysis_with_sweetviz.html', scale=0.92)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
# Report analysis_with_sweetviz.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from IPython.display import IFrame

# Assuming the Sweetviz report file is named 'analysis_with_sweetviz.html'
report_file = 'analysis_with_sweetviz.html'

# Display the Sweetviz report using IFrame
IFrame(src=report_file, width=1000, height=500)
# Out:
#         <iframe
#             width="1000"
#             height="500"
#             src="analysis_with_sweetviz.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
